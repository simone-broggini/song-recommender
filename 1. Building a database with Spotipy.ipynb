# %% [markdown]
# ## Loading credentials from the config file

# %%
import config
import pandas as pd
import requests

# %% [markdown]
# ## Initialising Spotipy API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# ## Collecting songs from Spotify's public playlists

# %% [markdown]
# The first step is building a database which contains the songs that will be provided as recommendation to the user. It is important to have songs of different genres so that whatever song the user inputs, there could be a corresponding match in the database.
#
# In order to speed up gathering songs, I opted to 'scrape' Spotify's own Public Playlists, assuming that those would contain a wide range of songs in different genres. According to the following webpage, there are 172 playlists edited by Spotify: https://open.spotify.com/user/spotify/playlists.

# %%
# retrieve the user "spotify"'s public playlists and retrieve their IDs
playlist_ids = []
offset = 0
limit = 50
while True:
    playlists = sp.user_playlists(user='spotify', limit=limit, offset=offset)
    playlist_ids.extend([playlist['id'] for playlist in playlists['items']])
    offset += limit
    if not playlists['next']:
        break

# %%
# select only the first 172 playlist_ids

playlist_ids = playlist_ids[:172]
playlist_ids
# Out:
# ['37i9dQZF1DXcBWIGoYBM5M',
#  '37i9dQZF1DX0XUsuxWHRQd',
#  '37i9dQZF1DX1lVhptIYRda',
#  '37i9dQZF1DX10zKzsJ2jva',
#  '37i9dQZF1DX4JAvHpjipBk',
#  '37i9dQZF1DX4sWSpwq3LiO',
#  '37i9dQZF1DX4SBhb3fqCJd',
#  '37i9dQZF1DWXRqgorJj26U',
#  '37i9dQZF1DX4dyzvuaRJ0n',
#  '37i9dQZF1DXcF6B6QPhFDv',
#  '37i9dQZF1DWXJfnUiYjUKT',
#  '37i9dQZF1DXcRXFNfZr7Tp',
#  '37i9dQZF1DX4o1oenSJRJd',
#  '37i9dQZF1DXbTxeAdrVG2l',
#  '37i9dQZF1DX4UtSsGT1Sbe',
#  '37i9dQZF1DWTJ7xPn4vNaz',
#  '37i9dQZF1DXaKIA8E7WcJj',
#  '37i9dQZF1DWSV3Tk4GO2fq',
#  '37i9dQZF1DWTwnEm1IYyoj',
#  '37i9dQZF1DX2A29LI7xHn1',
#  '37i9dQZF1DX2RxBh64BHjQ',
#  '37i9dQZF1DWVA1Gq4XHa6U',
#  '37i9dQZF1DWY4xHQp97fN6',
#  '37i9dQZF1DWX3387IZmjNa',
#  '37i9dQZF1DWYkaDif7Ztbp',
#  '37i9dQZF1DXan38dNVDdl4',
#  '37i9dQZF1DWSvKsRPPnv5o',
#  '37i9dQZF1DWUVpAXiEPK8P',
#  '37i9dQZF1DX0Tkc6ltcBfU',
#  '37i9dQZF1DX1YPTAhwehsC',
#  '37i9dQZF1DWTggY0yqBxES',
#  '37i9dQZF1DX0HRj9P7NxeE',
#  '37i9dQZF1DWT6SJaitNDax',
#  '37i9dQZF1DX2r0FByV5U4C',
#  '37i9dQZF1DWT2jS7NwYPVI',
#  '37i9dQZF1DX82GYcclJ3Ug',
#  '37i9dQZF1DX49jUV2NfGku',
#  '37i9dQZF1DX1Jg9KZ76Rr9',
#  '37i9dQZF1DX8FwnYE6PRvL',
#  '37i9dQZF1DX6mvEU1S6INL',
#  '37i9dQZF1DX9ZP5oobcNgA',
#  '37i9dQZF1DWZnzwzLBft6A',
#  '37i9dQZF1DX0FIO61wizta',
#  '37i9dQZF1DWXN6CDDJDZSt',
#  '37i9dQZF1DX0VplLa7NC0a',
#  '37i9dQZF1DWV0gynK7G6pD',
#  '37i9dQZF1DXafCT9DHTijq',
#  '37i9dQZF1DXcj60FvXn3Et',
#  '37i9dQZF1DXajUXy2f1Dsi',
#  '37i9dQZF1DXbIeCFU20wRm',
#  '37i9dQZF1DWVfS4Cdd3PNf',
#  '37i9dQZF1DX7cBprxbt1Fn',
#  '37i9dQZF1DWZtZ8vUCzche',
#  '37i9dQZF1DX1W7If2h64K3',
#  '37i9dQZF1DWWYlokKRoQoC']

# %% [markdown]
# ## Defining functions to get audio features from playlist
#
# After obtaining the playlist IDs of the selected playlists, it is necessary to define 2 functions:
#
# 1. Retrieve all tracks from the playlists
# 2. Extract audio features for the tracks

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
def get_audio_features(track_ids):
    audio_features = []
    for i in range(0, len(track_ids), 50):
        features_batch = sp.audio_features(track_ids[i:i+50])
        for features in features_batch:
            if features:
                audio_features.append(features)
    return audio_features

# %% [markdown]
# ## Creating a database with all songs in Spotify playlists

# %%
import time

start_time = time.time()

# Retrieve all tracks from the playlists
tracks = []
counter = 0
for playlist_id in playlist_ids:
    tracks += get_playlist_tracks('spotify', playlist_id)
    counter += 1
    if counter % 50 == 0:
        time.sleep(5) # sleep for 5 seconds every 50 playlists

# Filter out any tracks that are None
tracks = [track for track in tracks if track is not None]

# Extract audio features for the tracks
track_ids = [track['track']['id'] for track in tracks if track.get('track')]
track_ids = [id for id in track_ids if isinstance(id, str)]
audio_features = get_audio_features(track_ids)

# Build a pandas DataFrame from the audio features
df = pd.DataFrame(audio_features)

end_time = time.time()

print("Time taken:", end_time - start_time, "seconds")
# Out:
# Time taken: 122.13358116149902 seconds

# %%
df
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.696  0.8090    5    -8.254     1       0.0500        0.2520
# 1             0.707  0.6810    0    -4.325     1       0.0668        0.0632
# 2             0.644  0.7350    8    -5.747     1       0.0391        0.0521
# 3             0.538  0.7420    2    -5.355     1       0.1140        0.1380
# 4             0.715  0.6200    1    -6.005     0       0.0484        0.4170
# ...             ...     ...  ...       ...   ...          ...           ...
# 15374         0.261  0.0585    5   -22.054     0       0.0473        0.9870
# 15375         0.322  0.1290    1   -20.671     1       0.0437        0.9920
# 15376         0.311  0.1580   10   -16.724     1       0.0380        0.9690
# 15377         0.456  0.1090   10   -20.268     1       0.0604        0.9940
# 15378         0.362  0.0617    7   -24.588     1       0.0379        0.9910
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000128    0.2480   0.8570  132.962  audio_features
# 1              0.000005    0.0322   0.6460  117.999  audio_features
# 2              0.144000    0.1610   0.4180   88.980  audio_features
# 3              0.000047    0.0934   0.2500   96.107  audio_features
# 4              0.000000    0.0822   0.1720   97.950  audio_features
# ...                 ...       ...      ...      ...             ...
# 15374          0.872000    0.0887   0.1380   67.242  audio_features
# 15375          0.003620    0.1010   0.0449  129.018  audio_features
# 15376          0.901000    0.2400   0.1700   96.367  audio_features
# 15377          0.000266    0.0836   0.2400   68.848  audio_features
# 15378          0.916000    0.1710   0.3920   93.635  audio_features
#
#                            id                                   uri  \
# 0      6AQbmUe0Qwf5PZnt4HmTXv  spotify:track:6AQbmUe0Qwf5PZnt4HmTXv
# 1      0yLdNVWF3Srea0uzk55zFn  spotify:track:0yLdNVWF3Srea0uzk55zFn
# 2      1Qrg8KqiBpW07V7PNxwwwL  spotify:track:1Qrg8KqiBpW07V7PNxwwwL
# 3      5Z2MiIZ5I3jJvvmeWMLbOQ  spotify:track:5Z2MiIZ5I3jJvvmeWMLbOQ
# 4      2dHHgzDwk4BJdRwy9uXhTO  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# ...                       ...                                   ...
# 15374  2IAnU53rak76TpGpA515Xl  spotify:track:2IAnU53rak76TpGpA515Xl
# 15375  4zPZbj1sNxCOtU1CdgCK53  spotify:track:4zPZbj1sNxCOtU1CdgCK53
# 15376  2qYu0I9yKKpGnbySmN6w3K  spotify:track:2qYu0I9yKKpGnbySmN6w3K
# 15377  1xU1yjwGAGCCE3RiB8YKLe  spotify:track:1xU1yjwGAGCCE3RiB8YKLe
# 15378  4j8lYY8CxTPkY2DLLQT4hy  spotify:track:4j8lYY8CxTPkY2DLLQT4hy
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6AQbmUe0Qwf5...
# 1      https://api.spotify.com/v1/tracks/0yLdNVWF3Sre...
# 2      https://api.spotify.com/v1/tracks/1Qrg8KqiBpW0...
# 3      https://api.spotify.com/v1/tracks/5Z2MiIZ5I3jJ...
# 4      https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
# ...                                                  ...
# 15374  https://api.spotify.com/v1/tracks/2IAnU53rak76...
# 15375  https://api.spotify.com/v1/tracks/4zPZbj1sNxCO...
# 15376  https://api.spotify.com/v1/tracks/2qYu0I9yKKpG...
# 15377  https://api.spotify.com/v1/tracks/1xU1yjwGAGCC...
# 15378  https://api.spotify.com/v1/tracks/4j8lYY8CxTPk...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6AQb...       131013
# 1      https://api.spotify.com/v1/audio-analysis/0yLd...       200455
# 2      https://api.spotify.com/v1/audio-analysis/1Qrg...       153947
# 3      https://api.spotify.com/v1/audio-analysis/5Z2M...       272373
# 4      https://api.spotify.com/v1/audio-analysis/2dHH...       221520
# ...                                                  ...          ...
# 15374  https://api.spotify.com/v1/audio-analysis/2IAn...       439213
# 15375  https://api.spotify.com/v1/audio-analysis/4zPZ...       260187
# 15376  https://api.spotify.com/v1/audio-analysis/2qYu...       427653
# 15377  https://api.spotify.com/v1/audio-analysis/1xU1...       201640
# 15378  https://api.spotify.com/v1/audio-analysis/4j8l...       234987
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 15374               4
# 15375               4
# 15376               4
# 15377               5
# 15378               4
#
# [15379 rows x 18 columns]

# %%
df.to_csv('Data/df_top_playlists_all.csv', index=False)
